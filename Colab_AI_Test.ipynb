# %% [markdown]
# <a href="https://colab.research.google.com/github/ryanpollock/codespaces-jupyter/blob/main/Colab_AI_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], [1, 4, 2, 5])
plt.ylabel('some numbers')
plt.show()

# %%
# Importing the pandas library
import pandas as pd

# Creating a simple DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [25, 30, 35, 40, 45],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix']
}
df = pd.DataFrame(data)

# Displaying the first few rows of the DataFrame
print("First few rows of the DataFrame:")
print(df.head())

# Displaying basic statistical descriptions of the DataFrame
print("\nBasic Statistical Descriptions:")
print(df.describe())
# Out:
# First few rows of the DataFrame:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston
# 4      Eva   45      Phoenix
#
# Basic Statistical Descriptions:
#              Age
# count   5.000000
# mean   35.000000
# std     7.905694
# min    25.000000
# 25%    30.000000
# 50%    35.000000
# 75%    40.000000
# max    45.000000

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt

# Create the data set.
x_train = torch.randn(100, 1)
y_train = x_train + 0.1 * torch.randn(100, 1)

# Plot the data set.
plt.scatter(x_train, y_train)
plt.show()

# Create the model.
model = nn.Linear(1, 1)

# Define the loss function and optimizer.
loss_fn = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

# Train the model.
for epoch in range(50000):
    # Forward pass.
    y_pred = model(x_train)

    # Compute the loss.
    loss = loss_fn(y_pred, y_train)

    # Backward pass.
    loss.backward()

    # Update the weights.
    optimizer.step()

# Evaluate the model.
y_pred = model(x_train)
print(loss_fn(y_pred, y_train))

# Create a table of 10 predictions.
x_test = torch.randn(10, 1)
predictions = model(x_test)
print("Input\tOutput")
for x, y in zip(x_test, predictions):
    print(f"{x.item():.3f}\t{y.item():.3f}")
# Out:
# tensor(0.8703, grad_fn=<MseLossBackward0>)
# Input	Output
# -1.391	-2.418
# 0.207	0.795
# -1.111	-1.855
# -0.791	-1.211
# -0.931	-1.493
# 0.544	1.473
# -1.639	-2.917
# -1.243	-2.120
# -0.546	-0.720
# 0.643	1.671

# %%
import matplotlib.pyplot as plt

# Plot the initial training data.
plt.scatter(x_train, y_train, color='blue')

# Plot the new data that we're using the model to predict.

print(type(x_test))
print(type(predictions))
plt.scatter(x_test, predictions.detach().numpy(), color='red')

# Show the plot.
plt.show()
# Out:
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
